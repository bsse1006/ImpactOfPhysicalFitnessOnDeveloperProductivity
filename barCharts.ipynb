# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_excel("EncodedData.xlsx")
#print(dataset.head) 
dataset.dropna(inplace=True)
dataset.drop(columns=['Unnamed: 0'],inplace=True)
print(dataset.shape)
# Out:
# (48, 32)

# %%
teamRelated=[
    {'name': 'Average Sleep Duration', 'encoding': dict((v,k) for k,v in {'Less than 4 hours': 1, '4-6 Hours': 2, 
                                                                   'More than 10 hours':3, '6-8 Hours':4, 
                                                                   '8-10 Hours':5}.items())},
    {'name': 'Average Sleep Starting Time', 'encoding': dict((v,k) for k,v in {'After 5:00 am': 1, '3:01 am - 5:00 am': 2, 
                                                                   '1:01 am - 3:00 am':3, '11:00 pm - 1:00 am':4, 
                                                                   'Before 11pm':5}.items())},
    {'name': 'Average Breakfast Time', 'encoding': dict((v,k) for k,v in {'Do not take breakfast': 1, '11:01 am - 1:00 pm': 2, 
                                                                   'Before 6:00 am':3, '9:01 am - 11:00 am':4, 
                                                                   '6:00 am - 9:00 am':5}.items())},
    {'name': 'Average Lunch Time', 'encoding': dict((v,k) for k,v in {'Do not take lunch': 1, '4:01 pm - 6:00 pm': 2, 
                                                                   'Before 12:00 pm':3, '2:01 pm - 4:00 pm':4, 
                                                                   '12:00 pm - 2:00 pm':5}.items())},
    {'name': 'Average Dinner Time', 'encoding': dict((v,k) for k,v in {'Do not take Dinner': 1, 'After 11:00 pm': 2, 
                                                                   '9:01 pm - 11:00 pm':3, 'Before 7:00 pm':4, 
                                                                   '7:00 pm - 9:00 pm':5}.items())},
    {'name': 'Frequency of Physical Exercise', 'encoding': dict((v,k) for k,v in {'Never': 1, 'Occasionally': 2, 
                                                                   'Sometimes':3, 'Often':4, 
                                                                   'Always':5}.items())},
    {'name': 'Sitting Time', 'encoding': dict((v,k) for k,v in {'More than 12 hours': 1, '9 hours to 12 hours': 2, 
                                                                   '6 hours to 9 hours':3, '3 hours to 6 hours':4, 
                                                                   'Less than 3 hours':5}.items())},
    {'name': 'Resting Time', 'encoding': dict((v,k) for k,v in {'More than 2 hours': 1, '1:30 hours to 2 hours': 2, 
                                                                   'Less than 30 minutes':3, '1 hour to 1:30 hours':4, 
                                                                   '30 minutes to 1 hour':5}.items())},
    {'name': 'Frequency of Sickness', 'encoding': dict((v,k) for k,v in {'Never': 1, 'Occasionally': 2, 
                                                                   'Sometimes':3, 'Often':4, 
                                                                   'Always':5}.items())},
    {'name': 'Frequency of Smoking Habit', 'encoding': dict((v,k) for k,v in {'Never': 1, 'Occasionally': 2, 
                                                                   'Sometimes':3, 'Often':4, 
                                                                   'Always':5}.items())},
    {'name': 'Frequency of Vegetables in Diet', 'encoding': dict((v,k) for k,v in {'None': 1, '1': 2, 
                                                                   '2':3, '3':4, 
                                                                   'More than 3':5}.items())},
    {'name': 'Frequency of Sugar in Diet', 'encoding': dict((v,k) for k,v in {'Never': 1, 'Occasionally': 2, 
                                                                   'Weekly':3, 'Daily':4, 
                                                                   'Multiple times per day':5}.items())},
    {'name': 'Frequency of Fast Food in Diet', 'encoding': dict((v,k) for k,v in {'Never': 1, 'Occasionally': 2, 
                                                                   'Weekly':3, 'Daily':4, 
                                                                   'Multiple times per day':5}.items())},
    {'name': 'BMI', 'encoding': dict((v,k) for k,v in {'Obese': 1, 'Underweight': 2, 
                                                                   'Overweight':3, 'Normal':4}.items())}
]
productivityList=[
    'Interaction Willingness',
    'Decision Contribution',
    'Task Satisfaction',
    'External Interaction',
    'Deadline Crossing Frequency',
    'Overtime Frequency',
    'Frequency of Smartphone Usage',
    'Frequency of Being Late',
    'Frequency of Absence/Leave',
    'Appreciation/Motivation for Colleagues',
    'Cheerfulness'
]
prodName='External Interaction'

for prodName in productivityList:
    print("prodName", prodName)
    productivity_type = [1,2,3,4,5]#sorted(dataset[prodName].unique())
    print(productivity_type)

    for x in teamRelated:
        data = []
        bar_col = x['name']
        barcol_unique = sorted(dataset[bar_col].unique())

        for prod_type in productivity_type:
            bar_data = []
            for bar in barcol_unique:
                a = dataset[dataset[bar_col] == bar]
                query_result = a[a[prodName] == prod_type]

    #         query_result = pd.merge(a, b, how='inner', on=[bar_col, 'Productivity Level']).dropna(inplace=True)
            #print("query result*****")
            #print(query_result)

        #     print(prod_data)
                bar_data.append((query_result.shape[0]/a.shape[0]) * 100.0)
    #         print(bar_data)
            data.append(bar_data)
    #         print(len(data))
    #print("data***")
        #print(data)

        X = np.arange(dataset[bar_col].nunique())
        fig = plt.figure()
        ax = fig.add_axes([0,0,1,1])

        plt.xticks(range(len(barcol_unique)), x['encoding'].values() if len(x['encoding'].keys()) > 0 else range(len(barcol_unique)), size='small')
        plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')

    #     plt.tick_params(
    #     axis='x',          # changes apply to the x-axis
    #     which='both',      # both major and minor ticks are affected
    #     bottom=False,      # ticks along the bottom edge are off
    #     top=False,         # ticks along the top edge are off
    #     labelbottom=False) # labels along the bottom edge are off
    #     ax.set_xticklabels(range((len(barcol_unique))))
        colorlist = ['#ad2c2c', '#eb6542', '#596e92', '#7ec0a4', '#557965', '#559e65']
#         colorlist=['#ff0000','#005ce6','#006600','#e6e600','#660066','ff9933']
        wid=0.15

        bar_list = []
        for i in range(len(data)):
            bar_list.append(ax.bar(X + wid*i, data[i], color = colorlist[i%5], width = wid))



        for bar in bar_list:
            for rect in bar:
                height = rect.get_height()
    #             plt.text(rect.get_x() + rect.get_width()/2.0, height, '%.2f' % float(height), ha='center', va='bottom', fontsize=10)
    #     labels = x['encoding']    
    #     rects = ax.patches
    #     for rect, encoding_label in zip(rects, barcol_unique):
    #         height = rect.get_height()        

    #         ax.text(rect.get_x() + rect.get_width(), height -2, labels[encoding_label] if len(labels.keys()) > 0 else encoding_label,
    #                 ha='center', va='bottom')
        #ax.bar(X + 0.00, data[0], color = '#ff0000', width = 0.15)
        #ax.bar(X + 0.15, data[1], color = '#005ce6', width = 0.15)
        #ax.bar(X + 0.30, data[2], color = '#006600', width = 0.15)
        #ax.bar(X + 0.45, data[3], color = '#e6e600', width = 0.15)
        #ax.bar(X + 0.60, data[4], color = '#660066', width = 0.15)
        plt.xlabel(x['name'])
        plt.ylabel(prodName)
        plt.title(prodName +" VS "+str(x['name']))
    #         plt.savefig(prodName+" "+str(x['name']))
# Out:
# prodName Interaction Willingness
# [1, 2, 3, 4, 5]
# prodName Decision Contribution
# [1, 2, 3, 4, 5]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:88: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:88: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...
